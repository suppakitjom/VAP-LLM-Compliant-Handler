# %%
import boto3
import os

# %%
# s3 = boto3.resource(
#     service_name='s3',
#     region_name='ap-southeast-1',
#     aws_access_key_id='AKIA5FTZDWSXCJ5X2SUW',
#     aws_secret_access_key='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',
# )
BUCKET = 'nacc-bucket-sg'



s3_client = boto3.client('s3')
response = s3_client.list_buckets()

response
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniforge3/envs/nacc/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/miniforge3/envs/nacc/lib/python3.9/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# amplify-amplifyvitereactt-amplifydataamplifycodege-x5lqijvocohf
# amplify-d29n4gt2qermum-ma-amplifydataamplifycodege-wmooyz0rxbbh
# cdk-hnb659fds-assets-905418355886-ap-southeast-2
# nacc-bucket
# nacc-bucket-sg
# vapchopchopimages
