# %%
import os
from config import LANGCHAIN_API_KEY, OPENAI_API_KEY, GEMINI_API_KEY, GOOGLE_API_KEY
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = LANGCHAIN_API_KEY
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %% [markdown]
# # Structured Output

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama
ON_PREM = True
if ON_PREM:
    model = ChatOllama(
    model="llama3.1",
    temperature=0,
)
else:
    model = ChatOpenAI(model="gpt-4o-mini")

# %%
from typing import Optional
from langchain_core.pydantic_v1 import BaseModel, Field

class Summarizer(BaseModel):
    '''
    Summary of Compliant
    '''
    Summary: str = Field(description="the summary of the complaint, be concise")
    AllegedParty: str = Field(description="The person(people) or/and organization(s) being accused (NOT THE ACCUSER), if there are multiple, separate them with comma")
    Accusation: str = Field(description="the action that the perpetrator is accused of")
    Location: str = Field(description="province, district, or subdistrict")
    Amount: str = Field(description="the amount of money, if there is any involved, i prefer numeric value with currency eg. 1,000,000 บาท if no money involved or specified, just leave N/A")
    
    def __str__(self):
        return f"Summary: {self.Summary}\nAllegedParty: {self.AllegedParty}\nAccusation: {self.Accusation}\nLocation: {self.Location}\nAmount: {self.Amount}"

structured_model = model.with_structured_output(Summarizer)
compliant = '''
"ยุทธพงศ์" แฉ "ทร." ตั้งงบซื้อยูเอวี แพงเกินราคาพันล้าน ส่อไม่โปร่งใส นายยุทธพงศ์ จรัสเสถียร ส.ส.มหาสารคาม พรรคเพื่อไทย อภิปรายต่อที่ประชุม วาระพิจารณาร่างพระราชบัญญัติ (พ.ร.บ.) งบประมาณรายจ่ายประจำปีงบประมาณ พ.ศ.2566 วงเงิน 3.185 ล้านล้านบาท วาระแรก เป็นวันสาม โดยเปิดประเด็นกับกระทรวงการคลังต่อการเปิดประมูลโครงการท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ซึ่งย้ำถึงการเปิดประมูลที่ส่อว่าไม่โปร่งใส ขัดต่อการประกาศวิสัยทัศน์ของหน่วยงาน ทั้งนี้ในกลางเดือนกรกฎหาคม หากพล.อ.ประยุทธ์ จันทร์โอชา นายกรัฐมนตรีและรมว.กลาโหม ฐานะประธานอีอีซี ไม่ทำให้โปร่งใส เกิดประโยชน์ต่อแผ่นดิน  จะถูกยื่นอภิปรายไม่ไว้วางใจ รวมถึงนายอาคม เติมพิทยาไพสิฐ รมว.คลัง ฐานะกรรมการที่ราชพัสดุ และนายสันติ พร้อมพัฒน์ รมช.คลังที่รับมอบอำนาจจากรมว.คลังให้เป็นกรรมการที่ราชพัสดุ แต่ก่อนอภิปรายไม่ไว้วางใจ ตนจะยื่นเรื่องต่อคณะกรรมการป้องกันและปราบปรามการทุจริตแห่งชาติ  (ป.ป.ช.)  เพื่อให้สอบกรรมการที่ราชพัสดุ จำนวน 6 คน ที่ยกเลิกการประมูลในครั้งแรก ทำให้บริษัทอีสวอเตอร์เสียสิทธิ์
'''

result = structured_model.invoke(compliant)
print(result)
# Out:
# Summary: การเปิดประมูลท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ที่ไม่โปร่งใส และการยกเลิกการประมูลครั้งแรก ทำให้บริษัทอีสวอเตอร์เสียสิทธิ
# AllegedParty: พล.อ.ประยุทธ์ จันทร์โอชา, นายอาคม เติมพิทยาไพสิฐ, นายสันติ พร้อมพัฒน์
# Accusation: การเปิดประมูลท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ที่ไม่โปร่งใส
# Location: ประเทศไทย
# Amount: N/A

# %%
import pandas as pd
data = pd.read_excel('Mock.xlsx',sheet_name='Sheet1')
data
# Out:
#                                             Complaint  \
# 0   วันที่ 17 สิงหาคม 2567\n\nเรื่อง ขอร้องเรียนเก...
# 1   วันที่ 17 สิงหาคม 2567\n\nเรื่อง แจ้งเรื่องพฤต...
# 2   เรื่อง ขอให้ตรวจสอบกิจกรรมส่งมอบกระเป๋ายา อสม....
# 3   เรื่อง ขอให้ตรวจสอบและเร่งดำเนินการซ่อมแซมถนนค...
# 4   เรื่อง ขอให้ตรวจสอบการดำเนินการโครงการจัดซื้อพ...
# 5   เรื่อง ขอให้ตรวจสอบโครงการพัฒนาน้ำบาดาลเพื่อกา...
# 6   เรื่อง ขอให้ตรวจสอบและเร่งแก้ไขปัญหาถนนคอนกรีต...
# 7   เรื่อง ขอให้ตรวจสอบการใช้รถยนต์ของสถานีตำรวจภู...
# 8   เรื่อง ขอให้ตรวจสอบการดำเนินโครงการขยายท่อน้ำป...
# 9   เรื่อง ขอให้ติดตามและตรวจสอบแนวทางการดำเนินโคร...
# 10  ‘บีทีเอส’ ร่อนเอกสารข่าวโต้ ‘รฟม.’ หลังประกาศใ...
# 11  ปฏิบัติการหมาเฝ้าบ้าน อยากเที่ยวทะเล ไม่ต้องรอ...
# 12  ชาวต้องแฉเมืองตรังเขาส่งมาให้แอดดูว่าเห็นรถยนต...
# 13  อาคารคอนกรีตเสริมเหล็ก 7 ชั้น ขึ้นเป็นโครงสร้า...
# 14  ลงพื้นที่ติดตามแนวทางการดำเนินโครงการ “ปรับแหล...
# 15  เก็บค่าจอดรถ..เข้ากระเป๋าใคร..? เครือข่ายชมรม ...
# 16  การประชุมศูนย์ปฏิบัติการป้องกันและปราบปรามการท...
# 17  การประมูลงานอาคารอเนก​ประสงค์​พัดลมแน่น ๆ ของเ...
# 18  กรมพัฒนาพลังงานทดแทนและอนุรักษ์พลังงาน ทำโครงก...
# 19  ผู้อำนวยการสำนักส่งเสริมเมล็ดพันธุ์ข้าวส่งเครื...
# 20  สำนักข่าวอิศรา ‘กรมธนารักษ์’แจ้ง‘วงษ์สยามฯ’เซ็...
# 21  ย้อนรอยอุบัติเหตุโดรนเฮอร์มีส-900 ตก ตปท. 3 คร...
# 22  ศูนย์ OTOP สมุทรปราการ การกระจายสินค้าสู่ตลาดโ...
# 23  "พาดหัวข้อข่าวดังนี้" "ฉาว ""ชาวอ่างทอง"" แฉ "...
# 24  สุดงง! เขื่อนคอนกรีตกันน้ำท่วม สอดไส้ไม้อัด สง...
# 25  4 ปี ยังไม่เสร็จ ท่อระบายน้ำ เทศบาลนครสุราษฎร์...
# 26  Smart Farm 8.5 แสน ซื้อมาทิ้ง.. พบเห็นกันอีกเย...
# 27  8.5 ล้าน​ ทิ้งร้างมา​ 7​ ปี ไปตรงไหนเจอตรงนั้น...
# 28  สร้างแล้วไม่ได้ใช้ประโยชน์ บ่อน้ำร้อนสวนโมกข์น...
# 29  สภาพถนนที่ถูกฟื้นฟูด้วยงบ 14.9 ล้าน⁉️\n.\nในกล...
# 30  เจออีกแล้ว จุดบริการน้ำแร่สร้างแล้วทิ้ง\n\nเมื...
# 31  23.9ล้าน ท่าเทียบเรือทิ้งร้าง \nกรมเจ้าท่า ดำเ...
# 32  3 ปี 10.5 ล้าน ไม่ได้ใช้งาน\nเครือข่าย STRONG ...
# 33  กรณีที่ปรากฏในสื่อสังคมออนไลน์ว่ามีการใช้งบประ...
# 34  การประชุมศูนย์ปฏิบัติการป้องกันและปราบปรามการท...
# 35  ไม่อยากเกี่ยวข้องกันแหละดูออก ลงคลองได้ลงไปแล้...
# 36  34.6 ล้านงานห่วยๆ แขวงทางหลวงภูเก็ต\nเครือข่าย...
# 37  Strong ภาคใต้ ขอปรึกษาหน่อยครับ กรณีสร้างถนนบุ...
# 38  OpenChat "Strongภาคใต้" ได้โพสต์วีดีโออาคารถูก...
# 39  หนีกระเจิง! นักพนันลอบเปิดชนไก่ที่พัทลุง อ้างจ...
# 40  ทนไม่ไหว! ชาวบ้านจี้ตรวจสอบพบการลักลอบถางป่าบน...
# 41  รัตภูมิ ทนได้ตั้งสองเดือน\nถนนลาดยาง ขนาดกว้าง...
# 42  ลงพื้นที่ร่วมกับชมรม STRONG – จิตพอเพียงต้านทุ...
# 43  25 ล้านพังยังไม่ทันส่งงาน\nถนนสร้างใหม่ หน้าศู...
#
#                                     Category_Assigned
# 0                                      จัดซื้อจัดจ้าง
# 1   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 2   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 3   ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 4   ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 5   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส่...
# 6                                       ร่ำรวยผิดปกติ
# 7        ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 8                                      ออกเอกสารสิทธิ
# 9   การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 10  เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 11                                     จัดซื้อจัดจ้าง
# 12       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 13                                     ออกเอกสารสิทธิ
# 14  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 15  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 16  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 17  การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส่...
# 18                                      ร่ำรวยผิดปกติ
# 19   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 20   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 21   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 22                                     จัดซื้อจัดจ้าง
# 23                                     จัดซื้อจัดจ้าง
# 24                                     จัดซื้อจัดจ้าง
# 25       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 26       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 27       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 28                                     ออกเอกสารสิทธิ
# 29                                     ออกเอกสารสิทธิ
# 30                                     ออกเอกสารสิทธิ
# 31  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 32  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 33  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 34  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 35  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 36  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 37  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 38  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 39  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 40   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส...
# 41   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส...
# 42                                      ร่ำรวยผิดปกติ
# 43                                      ร่ำรวยผิดปกติ

# %%
data['temp'] = data['Complaint'].apply(lambda x: structured_model.invoke(x))
data['Summary'] = data['temp'].apply(lambda x: x.Summary)
data['AllegedParty'] = data['temp'].apply(lambda x: x.AllegedParty)
data['Accusation'] = data['temp'].apply(lambda x: x.Accusation)
data['Location'] = data['temp'].apply(lambda x: x.Location)
data['Amount'] = data['temp'].apply(lambda x: x.Amount)
data = data.drop(columns=['temp'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 data['temp'] = data['Complaint'].apply(lambda x: structured_model.invoke(x))
# ----> 2 data['Summary'] = data['temp'].apply(lambda x: x.Summary)
#       3 data['AllegedParty'] = data['temp'].apply(lambda x: x.AllegedParty)
#       4 data['Accusation'] = data['temp'].apply(lambda x: x.Accusation)
#
# File ~/miniconda3/envs/vap/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/miniconda3/envs/vap/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniconda3/envs/vap/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/vap/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/vap/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 2, in <lambda>(x)
#       1 data['temp'] = data['Complaint'].apply(lambda x: structured_model.invoke(x))
# ----> 2 data['Summary'] = data['temp'].apply(lambda x: x.Summary)
#       3 data['AllegedParty'] = data['temp'].apply(lambda x: x.AllegedParty)
#       4 data['Accusation'] = data['temp'].apply(lambda x: x.Accusation)
#
# AttributeError: 'NoneType' object has no attribute 'Summary'

# %%
data.to_excel('Mock.xlsx',index=False)

# %% [markdown]
# # JSON

# %%
# read string into json object
import json
from langchain_core.prompts import ChatPromptTemplate
ON_PREM = True
if ON_PREM:
    json_llm = ChatOllama(model="gemma2",format="json")
else:
    llm = ChatOpenAI(model="gpt-4o-mini")
    json_llm = llm.bind(response_format={"type": "json_object"})


prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            '''You are a helpful assistant that digests a complaint given into JSON format as follow:
    ### format
     Summary: '...', AllegedParty: '...', Accusation: '...', Location: '...', Amount: '...'
    
    ### field description
     where Summary is the concise summary of the complaint, and just explain what the alleged party is accused of, 
     AllegedParty is the person(people) or/and organization(s) being accused (NOT THE ACCUSER), if there are multiple, separate them with comma, 
     Accusation is the action that the perpetrator is accused of, 
     Location is the province, district, or subdistrict, Amount is the amount of money, if there is any involved, in the format of (number) บาท for example 1,000,000 บาท
    
    ### additional information
     the Summary is the only field that is required. if information is not explicitly available for any other field, just leave it as empty string
     EVERY FIELD MUST BE FILLED IN FORMAL THAI LANGUAGE''',
        ),
        ("human", "{complaint}"),
    ]
)

chain = prompt | json_llm
compliant = '''
"ยุทธพงศ์" แฉ "ทร." ตั้งงบซื้อยูเอวี แพงเกินราคาพันล้าน ส่อไม่โปร่งใส นายยุทธพงศ์ จรัสเสถียร ส.ส.มหาสารคาม พรรคเพื่อไทย อภิปรายต่อที่ประชุม วาระพิจารณาร่างพระราชบัญญัติ (พ.ร.บ.) งบประมาณรายจ่ายประจำปีงบประมาณ พ.ศ.2566 วงเงิน 3.185 ล้านล้านบาท วาระแรก เป็นวันสาม โดยเปิดประเด็นกับกระทรวงการคลังต่อการเปิดประมูลโครงการท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ซึ่งย้ำถึงการเปิดประมูลที่ส่อว่าไม่โปร่งใส ขัดต่อการประกาศวิสัยทัศน์ของหน่วยงาน ทั้งนี้ในกลางเดือนกรกฎหาคม หากพล.อ.ประยุทธ์ จันทร์โอชา นายกรัฐมนตรีและรมว.กลาโหม ฐานะประธานอีอีซี ไม่ทำให้โปร่งใส เกิดประโยชน์ต่อแผ่นดิน  จะถูกยื่นอภิปรายไม่ไว้วางใจ รวมถึงนายอาคม เติมพิทยาไพสิฐ รมว.คลัง ฐานะกรรมการที่ราชพัสดุ และนายสันติ พร้อมพัฒน์ รมช.คลังที่รับมอบอำนาจจากรมว.คลังให้เป็นกรรมการที่ราชพัสดุ แต่ก่อนอภิปรายไม่ไว้วางใจ ตนจะยื่นเรื่องต่อคณะกรรมการป้องกันและปราบปรามการทุจริตแห่งชาติ  (ป.ป.ช.)  เพื่อให้สอบกรรมการที่ราชพัสดุ จำนวน 6 คน ที่ยกเลิกการประมูลในครั้งแรก ทำให้บริษัทอีสวอเตอร์เสียสิทธิ์
'''
result = chain.invoke(
    {
        "complaint": compliant,
    }
)
result_json = json.loads(result.content)
result_json
# Out:
# {'Summary': 'นายยุทธพงศ์ จรัสเสถียร ส.ส.มหาสารคาม พรรคเพื่อไทย อภิปรายต่อที่ประชุม วาระพิจารณาร่างพระราชบัญญัติ (พ.ร.บ.) งบประมาณรายจ่ายประจำปีงบประมาณ พ.ศ.2566 ว่ากระทรวงการคลัง เปิดประมูลโครงการท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ที่ส่อว่าไม่โปร่งใส ขัดต่อการประกาศวิสัยทัศน์ของหน่วยงาน',
#  'AllegedParty': 'พล.อ.ประยุทธ์ จันทร์โอชา, นายอาคม เติมพิทยาไพสิฐ, นายสันติ พร้อมพัฒน์, กรรมการที่ราชพัสดุ จำนวน 6 คน',
#  'Accusation': 'เปิดประมูลโครงการท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี) ที่ไม่โปร่งใส, ยกเลิกการประมูลโครงการท่อส่งน้ำในเขตพัฒนาเศรษฐกิจพิเศษ (อีอีซี)',
#  'Location': '',
#  'Amount': ''}

# %%
import pandas as pd
data = pd.read_excel('Mock.xlsx',sheet_name='Sheet1')

# %%
data['temp'] = data['Complaint'].apply(lambda x: chain.invoke({
        "complaint": x,
    }).content)
data['temp'] = data['temp'].apply(lambda x: json.loads(x))
data['Summary'] = data['temp'].apply(lambda x: x['Summary'])
data['AllegedParty'] = data['temp'].apply(lambda x: x['AllegedParty'])
data['Accusation'] = data['temp'].apply(lambda x: x['Accusation'])
data['Location'] = data['temp'].apply(lambda x: x['Location'])
data['Amount'] = data['temp'].apply(lambda x: x['Amount'])
data = data.drop(columns=['temp'])

# %%
data
# Out:
#                                             Complaint  \
# 0   วันที่ 17 สิงหาคม 2567\n\nเรื่อง ขอร้องเรียนเก...
# 1   วันที่ 17 สิงหาคม 2567\n\nเรื่อง แจ้งเรื่องพฤต...
# 2   เรื่อง ขอให้ตรวจสอบกิจกรรมส่งมอบกระเป๋ายา อสม....
# 3   เรื่อง ขอให้ตรวจสอบและเร่งดำเนินการซ่อมแซมถนนค...
# 4   เรื่อง ขอให้ตรวจสอบการดำเนินการโครงการจัดซื้อพ...
# 5   เรื่อง ขอให้ตรวจสอบโครงการพัฒนาน้ำบาดาลเพื่อกา...
# 6   เรื่อง ขอให้ตรวจสอบและเร่งแก้ไขปัญหาถนนคอนกรีต...
# 7   เรื่อง ขอให้ตรวจสอบการใช้รถยนต์ของสถานีตำรวจภู...
# 8   เรื่อง ขอให้ตรวจสอบการดำเนินโครงการขยายท่อน้ำป...
# 9   เรื่อง ขอให้ติดตามและตรวจสอบแนวทางการดำเนินโคร...
# 10  ‘บีทีเอส’ ร่อนเอกสารข่าวโต้ ‘รฟม.’ หลังประกาศใ...
# 11  ปฏิบัติการหมาเฝ้าบ้าน อยากเที่ยวทะเล ไม่ต้องรอ...
# 12  ชาวต้องแฉเมืองตรังเขาส่งมาให้แอดดูว่าเห็นรถยนต...
# 13  อาคารคอนกรีตเสริมเหล็ก 7 ชั้น ขึ้นเป็นโครงสร้า...
# 14  ลงพื้นที่ติดตามแนวทางการดำเนินโครงการ “ปรับแหล...
# 15  เก็บค่าจอดรถ..เข้ากระเป๋าใคร..? เครือข่ายชมรม ...
# 16  การประชุมศูนย์ปฏิบัติการป้องกันและปราบปรามการท...
# 17  การประมูลงานอาคารอเนก​ประสงค์​พัดลมแน่น ๆ ของเ...
# 18  กรมพัฒนาพลังงานทดแทนและอนุรักษ์พลังงาน ทำโครงก...
# 19  ผู้อำนวยการสำนักส่งเสริมเมล็ดพันธุ์ข้าวส่งเครื...
# 20  สำนักข่าวอิศรา ‘กรมธนารักษ์’แจ้ง‘วงษ์สยามฯ’เซ็...
# 21  ย้อนรอยอุบัติเหตุโดรนเฮอร์มีส-900 ตก ตปท. 3 คร...
# 22  ศูนย์ OTOP สมุทรปราการ การกระจายสินค้าสู่ตลาดโ...
# 23  "พาดหัวข้อข่าวดังนี้" "ฉาว ""ชาวอ่างทอง"" แฉ "...
# 24  สุดงง! เขื่อนคอนกรีตกันน้ำท่วม สอดไส้ไม้อัด สง...
# 25  4 ปี ยังไม่เสร็จ ท่อระบายน้ำ เทศบาลนครสุราษฎร์...
# 26  Smart Farm 8.5 แสน ซื้อมาทิ้ง.. พบเห็นกันอีกเย...
# 27  8.5 ล้าน​ ทิ้งร้างมา​ 7​ ปี ไปตรงไหนเจอตรงนั้น...
# 28  สร้างแล้วไม่ได้ใช้ประโยชน์ บ่อน้ำร้อนสวนโมกข์น...
# 29  สภาพถนนที่ถูกฟื้นฟูด้วยงบ 14.9 ล้าน⁉️\n.\nในกล...
# 30  เจออีกแล้ว จุดบริการน้ำแร่สร้างแล้วทิ้ง\n\nเมื...
# 31  23.9ล้าน ท่าเทียบเรือทิ้งร้าง \nกรมเจ้าท่า ดำเ...
# 32  3 ปี 10.5 ล้าน ไม่ได้ใช้งาน\nเครือข่าย STRONG ...
# 33  กรณีที่ปรากฏในสื่อสังคมออนไลน์ว่ามีการใช้งบประ...
# 34  การประชุมศูนย์ปฏิบัติการป้องกันและปราบปรามการท...
# 35  ไม่อยากเกี่ยวข้องกันแหละดูออก ลงคลองได้ลงไปแล้...
# 36  34.6 ล้านงานห่วยๆ แขวงทางหลวงภูเก็ต\nเครือข่าย...
# 37  Strong ภาคใต้ ขอปรึกษาหน่อยครับ กรณีสร้างถนนบุ...
# 38  OpenChat "Strongภาคใต้" ได้โพสต์วีดีโออาคารถูก...
# 39  หนีกระเจิง! นักพนันลอบเปิดชนไก่ที่พัทลุง อ้างจ...
# 40  ทนไม่ไหว! ชาวบ้านจี้ตรวจสอบพบการลักลอบถางป่าบน...
# 41  รัตภูมิ ทนได้ตั้งสองเดือน\nถนนลาดยาง ขนาดกว้าง...
# 42  ลงพื้นที่ร่วมกับชมรม STRONG – จิตพอเพียงต้านทุ...
# 43  25 ล้านพังยังไม่ทันส่งงาน\nถนนสร้างใหม่ หน้าศู...
#
#                                     Category_Assigned  \
# 0                                      จัดซื้อจัดจ้าง
# 1   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 2   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 3   ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 4   ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 5   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส่...
# 6                                       ร่ำรวยผิดปกติ
# 7        ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 8                                      ออกเอกสารสิทธิ
# 9   การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 10  เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์ส...
# 11                                     จัดซื้อจัดจ้าง
# 12       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 13                                     ออกเอกสารสิทธิ
# 14  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 15  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 16  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 17  การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส่...
# 18                                      ร่ำรวยผิดปกติ
# 19   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 20   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 21   เรียกรับสินบน ให้/ขอให้ หรือรับว่าจะให้ทรัพย์...
# 22                                     จัดซื้อจัดจ้าง
# 23                                     จัดซื้อจัดจ้าง
# 24                                     จัดซื้อจัดจ้าง
# 25       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 26       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 27       ยักยอก/เบียดบังเงินหรือทรัพย์สินของทางราชการ
# 28                                     ออกเอกสารสิทธิ
# 29                                     ออกเอกสารสิทธิ
# 30                                     ออกเอกสารสิทธิ
# 31  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 32  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 33  การบริหารงานบุคคล (การบรรจุ/แต่งตั้ง/เลื่อนตำแ...
# 34  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 35  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 36  ทุจริตในการจัดทำงบประมาณ/โครงการ/เบิกจ่ายเงินใ...
# 37  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 38  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 39  ปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยมิชอบหรือ...
# 40   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส...
# 41   การขัดกันระหว่างประโยชน์ส่วนบุคคลและประโยชน์ส...
# 42                                      ร่ำรวยผิดปกติ
# 43                                      ร่ำรวยผิดปกติ
#
#                                               Summary  \
# 0   กรมท่าอากาศยานถูกกล่าวหาว่าโครงการก่อสร้างบ้าน...
# 1   เจ้าหน้าที่ข้าราชการในพื้นที่เรียกรับเงินใต้โต...
# 2   เรื่อง ขอให้ตรวจสอบกิจกรรมส่งมอบกระเป๋ายา อสม....
# 3   ขอให้ตรวจสอบและเร่งดำเนินการซ่อมแซมถนนคอนกรีตเ...
# 4   ขอให้ตรวจสอบการดำเนินการโครงการจัดซื้อพร้อมติด...
# 5   ขอให้ตรวจสอบโครงการพัฒนาน้ำบาดาลเพื่อการเกษตรแ...
# 6   ขอให้ตรวจสอบและเร่งแก้ไขปัญหาถนนคอนกรีตในพื้นท...
# 7   มีการร้องเรียนว่ารถยนต์ของสถานีตำรวจภูธร อ.กัน...
# 8   ร้องเรียนว่าโครงการขยายท่อน้ำประปาของเทศบาลตำบ...
# 9   ขอให้ติดตามและตรวจสอบแนวทางการดำเนินโครงการ "ป...
# 10  บีทีเอสโต้ว่า รฟม. นำเอกสารข่าวไปร่อนหลังประกา...
# 11  อบต.ชอนม่วง จ.ลพบุรี จัดทริป 3 วัน 2 คืน  พาลู...
# 12  ชาวต้องแฉเมืองตรังเขาส่งมาให้แอดดูว่าเห็นรถยนต...
# 13  การก่อสร้างอาคารผู้ป่วยนอก และอุบัติเหตุฉุกเฉิ...
# 14  โครงการส่งน้ำและบำรุงรักษาโก-ลก ถูกกล่าวหาว่า ...
# 15  เครือข่ายชมรม STRONG - ต้านทุจริตจังหวัดพัทลุง...
# 16                 การขุดลอกแหล่งน้ำโดยเจ้าหน้าที่รัฐ
# 17  การประมูลงานอาคารอเนกประสงค์พัดลมแน่น ๆ ของเทศ...
# 18  กรมพัฒนาพลังงานทดแทนและอนุรักษ์พลังงาน ได้ทำโค...
# 19  ผู้อำนวยการสำนักส่งเสริมเมล็ดพันธุ์ข้าวส่งเครื...
# 20  กรมธนารักษ์แจ้งให้บริษัท วงษ์สยามก่อสร้าง จำกั...
# 21  กองทัพเรือไทยได้ตัดสินจะจัดซื้อโดรนหรืออากาศยา...
# 22  ศูนย์ OTOP สมุทรปราการ การกระจายสินค้าสู่ตลาดโ...
# 23  ชาวอ่างทองแฉเขื่อนเรียงหินงบ 40 ล้าน สร้างเสร็...
# 24  ชาวบ้านสงสัยว่าเขื่อนเรียงหินที่เพิ่งสร้างเสร็...
# 25  เทศบาลนครสุราษฎร์ธานี ก่อสร้างท่อระบายน้ำและทา...
# 26  โครงการสมาร์ทฟาร์มภายในมหาวิทยาลัย จัดซื้อมาแล...
# 27  อ้างว่าโครงการพัฒนาแหล่งท่องเที่ยวเชิงอนุรักษ์...
# 28  โครงการปรับปรุงแหล่งท่องเที่ยวบ่อน้ำพุร้อนธรรม...
# 29  โครงการซ่อมฟื้นฟูทางหลวงชนบทมีสภาพทรุดโทรมไม่ส...
# 30  เครือข่าย STRONG อ.ท่าศาลาได้ตรวจสอบจุดบริการน...
# 31  กรมเจ้าท่าสร้างท่าเทียบเรือบริเวณชายทะเลหมู่ 3...
# 32  เครือข่าย STRONG จังหวัดกระบี่ ตั้งข้อสงสัยกรณ...
# 33           การทำลวดลายบนถนนโดยใช้งบประมาณ 2 ล้านบาท
# 34                 การขุดลอกแหล่งน้ำโดยเจ้าหน้าที่รัฐ
# 35  กล่าวหาว่ามีการทุจริตเบิกเงินงบประมาณเพื่อก่อส...
# 36  เครือข่าย STRONG จังหวัดภูเก็ต พบเห็นความผิดปก...
# 37  การก่อสร้างถนนบุกเบิกริมคลองโดยองค์กรปกครองส่ว...
# 38  OpenChat "Strongภาคใต้" ได้โพสต์วีดีโออาคารถูก...
# 39  ลักลอบเปิดสนามชนไก่ที่พัทลุง โดยอ้างจ่ายเงินให...
# 40  พบการลักลอบถางป่าไม้สมบูรณ์บนเกาะใหญ่กลางทะเลส...
# 41  ถนนลาดยางที่สร้างโดย อบต.ท่าชะมวง จ.สงขลา แตกก...
# 42  ลงพื้นที่ร่วมกับชมรม STRONG – จิตพอเพียงต้านทุ...
# 43         ถนนซอร์ฟ ความชื้นพื้นทางสูง ส่งผลให้ถนนพัง
#
#                                          AllegedParty  \
# 0            กรมท่าอากาศยาน, บริษัทอันนาเทรดดิ้งจำกัด
# 1                       เจ้าหน้าที่ข้าราชการในพื้นที่
# 2     เทศบาลนครอุดรธานี, บริษัท จีวาน โซลูชั่น จำกัด
# 3                               เทศบาลเมืองปราจีนบุรี
# 4                      เทศบาลเมืองท่าโขลง, ผู้รับเหมา
# 5                                 กรมทรัพยากรน้ำบาดาล
# 6                                           นายก อบต.
# 7                      สถานีตำรวจภูธร อ.กันตัง จ.ตรัง
# 8                                   เทศบาลตำบลคลองขุด
# 9                     โครงการส่งน้ำและบำรุงรักษาโก-ลก
# 10                                               รฟม.
# 11                               อบต.ชอนม่วง จ.ลพบุรี
# 12  สถานีตำรวจภูธร (สภ.) แห่งหนึ่งในพื้นที่ อ.กันต...
# 13  บริษัท เจมิไนย์ แอนด์ แอสโซซิเอท จำกัด, บริษัท...
# 14                    โครงการส่งน้ำและบำรุงรักษาโก-ลก
# 15                                              เอกชน
# 16
# 17                                           บ.เอส77
# 18             กรมพัฒนาพลังงานทดแทนและอนุรักษ์พลังงาน
# 19            ผู้อำนวยการสำนักส่งเสริมเมล็ดพันธุ์ข้าว
# 20                      บริษัท วงษ์สยามก่อสร้าง จำกัด
# 21            บริษัท Elbit Systems Ltd ประเทศอิสราเอล
# 22                             ศูนย์ OTOP สมุทรปราการ
# 23                            กรมโยธาธิการและผังเมือง
# 24                                 ผู้รับเหมาก่อสร้าง
# 25                        บริษัทเอกชนรายใหญ่ในจังหวัด
# 26  หน่วยงานที่จัดซื้อโครงการประกวดราคาซื้อชุดปฏิบ...
# 27                            ที่ทำการปกครองอำเภอไชยา
# 28                                          อำเภอไชยา
# 29        กรมทางหลวงชนบท, ห้างหุ้นส่วนจำกัด สุขศรัณย์
# 30             สำนักทรัพยากรน้ำบาดาลเขต 6 จังหวัดตรัง
# 31                                         กรมเจ้าท่า
# 32                  ห้างหุ้นส่วนจำกัด กันต์ธนา การค้า
# 33
# 34
# 35                                 ผู้รับจ้างก่อสร้าง
# 36                      แขวงทางหลวงภูเก็ต, กรมทางหลวง
# 37                                         อบต.บาโร๊ะ
# 38                      วิทยาลัยเกษตรและเทคโนโลยีตรัง
# 39                นายจิตพงค์ อินทะสระ และนักพนันชนไก่
# 40
# 41                      องค์การบริหารส่วนตำบลท่าชะมวง
# 42
# 43                            ศูนย์ฯ สงขลา กรมทางหลวง
#
#                                            Accusation  \
# 0       ความล่าช้าในการก่อสร้าง, ทิ้งงานโดยผู้รับเหมา
# 1                                 เรียกรับเงินใต้โต๊ะ
# 2   การจัดซื้ออุปกรณ์วิทยาศาสตร์การแพทย์โดยวิธีเฉพ...
# 3     ไม่ได้รับการซ่อมแซมถนนคอนกรีตเสริมเหล็กที่ชำรุด
# 4   เอื้อประโยชน์แก่ผู้รับเหมา, คัดเลือกคู่สัญญาไม...
# 5   ปล่อยทิ้งโครงการพัฒนาน้ำบาดาลเพื่อการเกษตรแปลง...
# 6   ใช้ชื่อห้างของลูกน้องคนสนิทมารับงานก่อสร้างถนน...
# 7   จอดรถยนต์ของทางราชการที่บ้านพักส่วนบุคคลและใช้...
# 8   ดำเนินโครงการขยายท่อน้ำประปาแล้วแต่ระบบยังไม่ส...
# 9    ดำเนินการโครงการอย่างไม่โปร่งใสหรือมีประสิทธิภาพ
# 10                                 นำเอกสารข่าวไปร่อน
# 11  จัดทริปส่วนตัว disguised as an official trip t...
# 12  จอดรถยนต์ของ สภ. ในโรงรถของบ้านพักส่วนบุคคลเป็...
# 13                    ทิ้งงานล่าช้าการก่อสร้างโครงการ
# 14                                             ทุจริต
# 15  จัดเก็บผลประโยชน์จากที่ดินราชพัสดุ โดยให้เอกชน...
# 16                                     ขุดลอกแหล่งน้ำ
# 17                                  ฟันราคา, เฉือนชนะ
# 18  จัดซื้อวัสดุอุปกรณ์เพื่อทำโครงการไฟฟ้าพลังน้ำร...
# 19  ส่งเครื่องคัดทำความสะอาดเมล็ดพันธุ์ข้าวไม่ได้ม...
# 20  ลงนามในสัญญาโครงการบริหารและดำเนินกิจการระบบท่...
# 21     จัดจำหน่ายโดรนเฮอร์มีส-900 ให้กับกองทัพเรือไทย
# 22        การจัดสรรงบประมาณที่ไม่เหมาะสมและสิ้นเปลือง
# 23  ก่อสร้างเขื่อนป้องกันตลิ่งริมคลองบางแก้ว มีระย...
# 24  นำวัสดุไม้อัดมาซ่อนแทนคอนกรีตในรอยต่อผนังเขื่อ...
# 25  ก่อสร้างท่อระบายน้ำและทางเท้าถนนพ่อขุนทะเลยังไ...
# 26        จัดซื้อโครงการสมาร์ทฟาร์มมาแล้วไม่ได้ใช้งาน
# 27  ก่อสร้างโครงการแล้วเสร็จจัดงานเปิดโครงการได้ไม...
# 28  ปล่อยทิ้งร้างและไม่ดูแลรักษาโครงการปรับปรุงแหล...
# 29  ก่อสร้างถนนที่มีสภาพทรุดโทรมและไม่สมานกับงบประ...
# 30             ปล่อยทิ้งร้างจุดบริการน้ำแร่โดยไม่ดูแล
# 31  ก่อสร้างท่าเทียบเรือแล้วปล่อยรกร้าง, ไม่สนับสน...
# 32  ก่อสร้างโครงการพัฒนาแหล่งแช่น้ำพุร้อนเค็มเพื่อ...
# 33                                      ทำลวดลายบนถนน
# 34                                     ขุดลอกแหล่งน้ำ
# 35                             ทุจริตเบิกเงินงบประมาณ
# 36  ก่อสร้างงานทางหลวงไม่เป็นมาตรฐาน, การบดอัดไม่ไ...
# 37  ก่อสร้างถนนบุกเบิกริมคลองโดยไม่มีการประชาคมสอด...
# 38            สร้างอาคารแล้วทิ้งร้างโดยไม่มีการใช้งาน
# 39              ลักลอบเปิดสนามชนไก่โดยไม่ได้รับอนุญาต
# 40                                    ลักลอบถางป่าไม้
# 41                        สร้างถนนลาดยางไม่ได้มาตรฐาน
# 42  การทุจริตโครงการก่อสร้างถนนคอนกรีตเสริมเหล็ก พ...
# 43                 ก่อสร้างถนนไม่มาตรฐาน, ทำให้ถนนพัง
#
#                                              Location  \
# 0                                 จังหวัดสุราษฎร์ธานี
# 1                                     จังหวัดปทุมธานี
# 2                                เขตเทศบาลนครอุดรธานี
# 3                            เขตเทศบาลเมืองปราจีนบุรี
# 4                               เขตเทศบาลเมืองท่าโขลง
# 5   บ้านคลองวังทอง หมู่ 8 ตำบลคลองยาง อำเภอสวรรคโล...
# 6                         หมู่ 7 อ.รือเสาะ จ.นราธิวาส
# 7                                     อ.กันตัง จ.ตรัง
# 8     ตำบลคลองขุด อำเภอเมือง จังหวัด [จังหวัดของท่าน]
# 9   บ้านปลักปลา หมู่ 4 ตำบลโฆษิต อำเภอตากใบ จังหวั...
# 10
# 11                               จ.ลพบุรี, จ.จันทบุรี
# 12                                    อ.กันตัง จ.ตรัง
# 13                                        จังหวัดตรัง
# 14  บ้านปลักปลา หมู่4 ตำบลโฆษิต อำเภอตากใบ จังหวัด...
# 15       จังหวัดพัทลุง, บริเวณด้านหน้าสถานีรถไฟพัทลุง
# 16
# 17
# 18       บ้านห้วยน้ำผึ้ง ต.สบโขง อ.อมก๋อย จ.เชียงใหม่
# 19
# 20
# 21
# 22
# 23        พื้นที่หมู่ 6,7 ต.บ้านอิฐ อ.เมือง จ.อ่างทอง
# 24              หมู่ที่ 4 ต.โผงเผง อ.ป่าโมก จ.อ่างทอง
# 25                                  เมืองสุราษฎร์ธานี
# 26  ตำบลขุนทะเล อำเภอเมืองสุราษฎร์ธานี จังหวัดสุรา...
# 27      บ้านแหลมทราย ต.พุมเรียง อ.ไชยา จ.สุราษฎร์ธานี
# 28            ตำบลเลม็ด อำเภอไชยา จังหวัดสุราษฎร์ธานี
# 29                 อำเภอปากพนัง #จังหวัดนครศรีธรรมราช
# 30  หมู่ที่ 6 บ้านปลักจอก ต.ไทยบุรี อ.ท่าศาลา จ.นค...
# 31          หมู่ 3 ต.บางพระ อ.ปากพนัง จ.นครศรีธรรมราช
# 32                   ต.ห้วยน้ำขาว อ.คลองท่อม จ.กระบี่
# 33               ตำบลป่าตอง อำเภอกระทู้ จังหวัดภูเก็ต
# 34
# 35  หมู่ที่ 6 ของ อบต.โพธิ์ทอง อำเภอท่าศาลา จังหวั...
# 36  จังหวัดภูเก็ต, ทางหลวงหมายเลข 402 ตอน หมากปรก ...
# 37       อบต.บาโร๊ะ ม.1 บ.ปูแล ต.บาโร๊ะ อ.ยะหา จ.ยะลา
# 38                                               ตรัง
# 39                         อำเภอบางแก้ว จังหวัดพัทลุง
# 40  พื้นที่เกาะใหญ่ กลางทะเลสาบฮาลาบาลา บริเวณพื้น...
# 41                                  อ.รัตภูมิ จ.สงขลา
# 42  ซอยบ้านมั่นคง หมู่ 11 บ้านปากาดารอ ตำบลบานา อำ...
# 43                                อ.ป่าพะยอม จ.พัทลุง
#
#                                                Amount
# 0                                          44 ล้านบาท
# 1
# 2                                       7,318,925 บาท
# 3                                      10,000,000 บาท
# 4
# 5                                     113,000,000 บาท
# 6                                       6,352,200 บาท
# 7
# 8
# 9                                      21,000,000 บาท
# 10
# 11
# 12
# 13                                    500,000,000 บาท
# 14                                     21,000,000 บาท
# 15                                    10 บาท (ต่อคัน)
# 16
# 17
# 18                                      3,792,500 บาท
# 19
# 20                                     743.12 ล้านบาท
# 21                               4,060,551,936.11 บาท
# 22                                     70,000,000 บาท
# 23  44,520,000 บาท(สี่สิบสี่ล้านห้าแสนสองหมื่นบาทถ...
# 24
# 25                                     20,710,000 บาท
# 26                                        850,000 บาท
# 27                                      8,570,000 บาท
# 28                                     15,209,162 บาท
# 29                                     14,997,000 บาท
# 30
# 31                                     23,977,341 บาท
# 32                                     10,582,000 บาท
# 33                                      2,000,000 บาท
# 34
# 35                                        823,500 บาท
# 36                                     34,600,000 บาท
# 37
# 38
# 39                                  2,000 บาทต่อครั้ง
# 40
# 41                                      1,374,000 บาท
# 42
# 43                                     25,600,389 บาท

# %%
data.to_excel('Mock.xlsx',index=False)
